# %% [markdown]
# <a href="https://colab.research.google.com/github/alstjr98/2023_2_aiml/blob/main/230913_week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
team2 = pd.DataFrame({'Name' : ['김민석', '유태권', '정민석', '위지수', '이주영'],
                      'Hobby' : ['listening to music', 'watching football', 'playing game', 'watching volleyball', 'watching baseball'],
                      'Nationality': ['Kor', 'Kor', 'Kor', 'Kor', 'Kor']
                      }, index = ['kim', 'you', 'jung', 'wee', 'lee'])
team2
# Out:
#      Name                Hobby Nationality
# kim   김민석   listening to music         Kor
# you   유태권    watching football         Kor
# jung  정민석         playing game         Kor
# wee   위지수  watching volleyball         Kor
# lee   이주영    watching baseball         Kor

# %%
team2.to_csv('team2.csv', index = False)

# %%
team_2 = pd.read_csv("team2.csv")

# %%
team_2
# Out:
#   Name                Hobby Nationality
# 0  김민석   listening to music         Kor
# 1  유태권    watching football         Kor
# 2  정민석         playing game         Kor
# 3  위지수  watching volleyball         Kor
# 4  이주영    watching baseball         Kor

# %%
team_2.nunique()
# Out:
# Name           5
# Hobby          5
# Nationality    1
# dtype: int64

# %%
team_2.count()
# Out:
# Name           5
# Hobby          5
# Nationality    5
# dtype: int64

# %%
team_2['Age'] = [25, 24, 26, 25, 26]

# %%
team_2
# Out:
#   Name                Hobby Nationality  Age
# 0  김민석   listening to music         Kor   25
# 1  유태권    watching football         Kor   24
# 2  정민석         playing game         Kor   26
# 3  위지수  watching volleyball         Kor   25
# 4  이주영    watching baseball         Kor   26

# %%
team_2.mean()
# Out:
# <ipython-input-52-c762c904e48c>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   team_2.mean()
# Age    25.2
# dtype: float64

# %%
team_2['Age'].sum()
# Out:
# 126
